# %% [markdown]
# # PYTHON FOR DATA SCIENCE.

# %%
# Key concepts in Data Science.
# Data : text, videos, images, audio, numbers, or semi structured data (JSON, XML)
# Data mining
# Machine learning
# Statistical analysis
# Data visualization
# Big data
# Predictive analysis

# %%
# Understanding data science workflow.
# 1. Problem definition
# 2. Data acquisition / collection  .. data.gov, kaggle, web scraping, APIs, databases, etc.
# 3. Data cleaning / preparation   
# 4. EDA .. Exploratory Data Analysis

# Data Preparation and preprocessing
# - Missing data 
# - Wrong format
# - Null values
# - Duplicates

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Control display of seaborn data 
pd.options.display.max_columns=50
sns.set(style="darkgrid", rc={"axes.facecolor":"#CAF1DE"})

# %%
# Loading the dataset
df = pd.read_csv('bse_dataset.csv')
df
# Out:
#               Timestamp What is your gender?  Age What is your emotion?  \
# 0   05/07/2023 09:38:39                 Male   21               Content
# 1   05/07/2023 09:38:57        Marabou stock   45                 Weird
# 2   05/07/2023 09:39:09              Female    20                 Happy
# 3   05/07/2023 09:39:12                 Male   21                 Happy
# 4   05/07/2023 09:39:14               Female   21                 Happy
# ..                  ...                  ...  ...                   ...
# 92  05/07/2023 09:53:56              Female    68                   Sad
# 93  05/07/2023 09:54:13                 Male   29               Hopeful
# 94  05/07/2023 09:54:28                 Male   22      Fighting poverty
# 95  05/07/2023 09:54:36                 Male   23          good and bad
# 96  05/07/2023 09:54:52                 male   30                hunger
#
#    Year of birth What is your CGPA? Do you have a Girl Friend or BOY Friend  \
# ...

# %%
# Data Analysis Workflow
# Understanding our dataset
# Data cleaning
# Exploratory Data analysis
# Insight Data Visualization

# %%
# Understanding of data structure
# Checking shape of data (rows, columns)
df.shape
# Out:
# (97, 11)

# %%
# Checking column names
df.columns
# Out:
# Index(['Timestamp', 'What is your gender?', 'Age', 'What is your emotion?',
#        'Year of birth', 'What is your CGPA?',
#        'Do you have a Girl Friend or BOY Friend', 'Do you have Depression?',
#        'Do you have Anxiety?', 'Do you have Panic attack?',
#        'Did you have seek any specialist for a treatment? '],
#       dtype='object')

# %%
# Checking data types
df.dtypes
# Out:
# Timestamp                                             object
# What is your gender?                                  object
# Age                                                    int64
# What is your emotion?                                 object
# Year of birth                                         object
# What is your CGPA?                                    object
# Do you have a Girl Friend or BOY Friend               object
# Do you have Depression?                               object
# Do you have Anxiety?                                  object
# Do you have Panic attack?                             object
# Did you have seek any specialist for a treatment?     object
# dtype: object

# %%
# Checking for basic information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 11 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Timestamp                                           97 non-null     object
#  1   What is your gender?                                97 non-null     object
#  2   Age                                                 97 non-null     int64
#  3   What is your emotion?                               96 non-null     object
#  4   Year of birth                                       97 non-null     object
#  5   What is your CGPA?                                  97 non-null     object
#  6   Do you have a Girl Friend or BOY Friend             97 non-null     object
#  7   Do you have Depression?                             97 non-null     object
# ...

# %%
# Check null values
df.isnull().sum().sort_values(ascending = False)
# Out:
# What is your emotion?                                 1
# Timestamp                                             0
# What is your gender?                                  0
# Age                                                   0
# Year of birth                                         0
# What is your CGPA?                                    0
# Do you have a Girl Friend or BOY Friend               0
# Do you have Depression?                               0
# Do you have Anxiety?                                  0
# Do you have Panic attack?                             0
# Did you have seek any specialist for a treatment?     0
# dtype: int64

# %%
# Loading dataset two.
df2 = pd.read_csv('bse_dataset2.csv')
df2
# Out:
#            Timestamp What is your gender?   Age What is your emotion?  \
# 0   05/07/2023 09:38                 Male  21.0               Content
# 1   05/07/2023 09:38        Marabou stock  45.0                 Weird
# 2   05/07/2023 09:39              Female   20.0                 Happy
# 3   05/07/2023 09:39                 Male  21.0                 Happy
# 4   05/07/2023 09:39               Female  21.0                 Happy
# ..               ...                  ...   ...                   ...
# 92  05/07/2023 09:53              Female   68.0                   Sad
# 93  05/07/2023 09:54                 Male  29.0               Hopeful
# 94  05/07/2023 09:54                 Male  22.0      Fighting poverty
# 95  05/07/2023 09:54                 Male  23.0          good and bad
# 96  05/07/2023 09:54                 male  30.0                hunger
#
#    Year of birth What is your CGPA? Do you have a Girl Friend or BOY Friend  \
# ...

# %%
# Check null values in dataset two
df2.isnull().sum().sort_values(ascending = False)
# Out:
# Age                                                   2
# What is your emotion?                                 1
# Timestamp                                             0
# What is your gender?                                  0
# Year of birth                                         0
# What is your CGPA?                                    0
# Do you have a Girl Friend or BOY Friend               0
# Do you have Depression?                               0
# Do you have Anxiety?                                  0
# Do you have Panic attack?                             0
# Did you have seek any specialist for a treatment?     0
# dtype: int64

# %%
# Checking for basic information in the second dataset
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 11 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Timestamp                                           97 non-null     object
#  1   What is your gender?                                97 non-null     object
#  2   Age                                                 95 non-null     float64
#  3   What is your emotion?                               96 non-null     object
#  4   Year of birth                                       97 non-null     object
#  5   What is your CGPA?                                  97 non-null     object
#  6   Do you have a Girl Friend or BOY Friend             97 non-null     object
#  7   Do you have Depression?                             97 non-null     object
# ...

# %%
# Checking null values in percentages
for i in df2.columns:
    if df2[i].isnull().any():
        print(i, ":", df2[i].isnull().sum()*100/df2.shape[0], "%")
# Out:
# Age : 2.0618556701030926 %
# What is your emotion? : 1.0309278350515463 %

# %%
# Checking null values in figures
import missingno as msno
msno.bar(df2, color = "gray", fontsize = 12, figsize = (10, 5))
# Out:
# <Axes: >

# %%
# Checking for duplicates
df2.duplicated().sum()
# Out:
# 0

# %%
# Describe function
df2.describe().T
# Out:
#      count       mean       std   min   25%   50%   75%   max
# Age   95.0  22.936842  6.342713  19.0  21.0  21.0  22.5  68.0

# %%
# Describe function for object data types
df2.describe(include = "object").T
# Out:
#                                                    count unique  \
# Timestamp                                             97     13
# What is your gender?                                  97     10
# What is your emotion?                                 96     50
# Year of birth                                         97     18
# What is your CGPA?                                    97     61
# Do you have a Girl Friend or BOY Friend               97     14
# Do you have Depression?                               97     13
# Do you have Anxiety?                                  97     18
# Do you have Panic attack?                             97     13
# Did you have seek any specialist for a treatment?     97      9
#
#                                                                  top freq
# Timestamp                                           05/07/2023 09:40   23
# What is your gender?                                            Male   41
# ...

# %%
# Checking for unique values   # Show unique values in columns of df2
for i in df2.columns:
    print(i, ":", df2[i].unique())
# Out:
# Timestamp : ['05/07/2023 09:38' '05/07/2023 09:39' '05/07/2023 09:40'
#  '05/07/2023 09:41' '05/07/2023 09:42' '05/07/2023 09:43'
#  '05/07/2023 09:44' '05/07/2023 09:45' '05/07/2023 09:49'
#  '05/07/2023 09:51' '05/07/2023 09:52' '05/07/2023 09:53'
#  '05/07/2023 09:54']
# What is your gender? : ['Male' 'Marabou stock' 'Female ' 'Female' 'female' 'MALE' 'FEMALE' 'male'
#  'Yes' 'M']
# Age : [21. 45. 20. 23. nan 22. 24. 25. 28. 19. 50. 30. 68. 29.]
# What is your emotion? : ['Content' 'Weird' 'Happy' 'Happy ' 'irritated ' 'In a state of wonder'
#  'Sad' 'happy' 'Moody' 'fine' 'TIRED FOR NOW' 'Jolly' 'Frustrated'
#  'Anxious' 'HAPPY' 'calm' 'sad' 'Not sure' 'I hate nosense ' 'Joyful'
#  'Nonchalant ' 'excited' 'stressed' 'Relaxed' 'Angry ' 'leaning'
#  'Disgusted' 'Tired' 'Upset' 'Anger' 'angry' 'Sad ' 'Lonely' 'Happiness'
#  'sleepy' 'tired' 'stress' 'unhappy' 'happy ' 'care' nan 'Afraid '
#  'Scared' 'HAPPY ' 'Joy' 'Lonely ' 'panic' 'Hopeful' 'Fighting poverty'
# ...
