# %% [markdown]
# **PYTHON FOR DATA SCIENCE DAY TWO.**

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Control display of seaborn data 
pd.options.display.max_columns=50
sns.set(style="darkgrid", rc={"axes.facecolor":"#CAF1DE"})

# %%
# Loading the dataset
df = pd.read_csv('bse_dataset4.csv')
df
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
# Checking for basic information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 15 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Timestamp                                           168 non-null    object
#  1   gender                                              169 non-null    object
#  2   Age                                                 167 non-null    float64
#  3   emotion                                             168 non-null    object
#  4   YOB                                                 169 non-null    object
#  5   CGPA                                                169 non-null    object
#  6   Do you have a Girl Friend or BOY Friend             169 non-null    object
#  7   Do you have Depression?                             169 non-null    object
# ...

# %%
# Remove all rows with null values.
df2 = df.dropna()
df2
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
# Confirming that no null values are present.
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 160 entries, 0 to 168
# Data columns (total 15 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Timestamp                                           160 non-null    object
#  1   gender                                              160 non-null    object
#  2   Age                                                 160 non-null    float64
#  3   emotion                                             160 non-null    object
#  4   YOB                                                 160 non-null    object
#  5   CGPA                                                160 non-null    object
#  6   Do you have a Girl Friend or BOY Friend             160 non-null    object
#  7   Do you have Depression?                             160 non-null    object
# ...

# %%
# It modifies the DataFrame in-place, meaning it directly modifies the original DataFrame without creating a new one.
df3 = df.dropna(inplace=True)
df3

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 160 entries, 0 to 168
# Data columns (total 15 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Timestamp                                           160 non-null    object
#  1   gender                                              160 non-null    object
#  2   Age                                                 160 non-null    float64
#  3   emotion                                             160 non-null    object
#  4   YOB                                                 160 non-null    object
#  5   CGPA                                                160 non-null    object
#  6   Do you have a Girl Friend or BOY Friend             160 non-null    object
#  7   Do you have Depression?                             160 non-null    object
# ...

# %%
# After re-running , we return the original dataset with 169 rows.
df = pd.read_csv('datasets/bse_dataset4.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 15 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Timestamp                                           168 non-null    object
#  1   gender                                              169 non-null    object
#  2   Age                                                 167 non-null    float64
#  3   emotion                                             168 non-null    object
#  4   YOB                                                 169 non-null    object
#  5   CGPA                                                169 non-null    object
#  6   Do you have a Girl Friend or BOY Friend             169 non-null    object
#  7   Do you have Depression?                             169 non-null    object
# ...

# %%
df.fillna(value=100, inplace=True)
df
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 169 entries, 0 to 168
# Data columns (total 15 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Timestamp                                           169 non-null    object
#  1   gender                                              169 non-null    object
#  2   Age                                                 169 non-null    float64
#  3   emotion                                             169 non-null    object
#  4   YOB                                                 169 non-null    object
#  5   CGPA                                                169 non-null    object
#  6   Do you have a Girl Friend or BOY Friend             169 non-null    object
#  7   Do you have Depression?                             169 non-null    object
# ...

# %%
# Return rows with 100 in the Calories column.
filtered_df = df[df['Calories'] == 100]
filtered_df
# Out:
#                Timestamp gender   Age     emotion   YOB  CGPA  \
# 17   05/07/2023 09:39:47   Male  22.0  Frustrated  2001     5
# 27   05/07/2023 09:40:08   Male  22.0    Not sure  2001  3.74
# 91   05/07/2023 09:53:52   Male  22.0       panic  2001  3.78
# 118  05/07/2023 09:40:25   Male  22.0       Happy  2000   3.7
# 141  05/07/2023 09:41:30   Male  25.0       Happy  1998     5
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# 17                                       No                      No
# 27                                       No                     Yes
# 91                                      yes                     yes
# 118                                     Yes                      No
# 141                                     Yes                      No
#
#     Do you have Anxiety? Do you have Panic attack?  \
# 17                    No                        No
# 27                   Yes                        No
# ...

# %%
# Filling missing values with mean, median and mode.
# Mean.
df = pd.read_csv('bse_dataset4.csv')
m = df['Age'].mean()
print(m)
df['Age'].fillna(m, inplace=True)
# Out:
# 22.49700598802395

# %%
# Return rows with the mean.
fil_df = df[df['Age'] == m]
fil_df
# Out:
#               Timestamp  gender        Age emotion   YOB  CGPA  \
# 46  05/07/2023 09:41:01    Male  22.497006   Upset  2002  3.71
# 73  05/07/2023 09:43:05  female  22.497006   happy  2002   4.2
#
#    Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# 46                                     Yes                      No
# 73                                     yes                      no
#
#    Do you have Anxiety? Do you have Panic attack?  \
# 46                   No                        No
# 73                  yes                        no
#
#    Did you have seek any specialist for a treatment?   Duration  Pulse  \
# 46                                                 No        60    109
# 73                                                 no       150     97
#
#     Maxpulse  Calories
# 46       153     387.6
# 73       127     953.2

# %%
# Median.
df = pd.read_csv('bse_dataset4.csv')
me = df['Age'].median()
print(me)
df['Age'].fillna(me, inplace=True)
# Out:
# 21.0

# %%
# Return rows with the median.
fill_df = df[df['Age'] == me]
fill_df
# Out:
#                Timestamp   gender   Age      emotion   YOB  CGPA  \
# 0    05/07/2023 09:38:39     Male  21.0      Content  2002  4.22
# 3    05/07/2023 09:39:12     Male  21.0        Happy  2003  4.37
# 4    05/07/2023 09:39:14   Female  21.0        Happy  2002  3.63
# 6    05/07/2023 09:39:21   female  21.0   irritated   2001  3.88
# 15   05/07/2023 09:39:46     Male  21.0        Jolly  2002   4.5
# ..                   ...      ...   ...          ...   ...   ...
# 157  05/07/2023 09:42:48  Female   21.0       Happy   2002  3.67
# 160  05/07/2023 09:43:08   Female  21.0  Nonchalant   2002   4.5
# 162  05/07/2023 09:43:36     male  21.0     stressed  2002   4.4
# 163  05/07/2023 09:43:56     Male  21.0      Relaxed  2001   4.5
# 167  05/07/2023 09:44:35   Female  21.0          sad  2001   3.8
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# 0                                        No                      No
# ...

# %% [markdown]
# EXERCISE.1  Filling missing values with mode.

# %%
# Mode.     iloc[0] is used to access the first row of the mode DataFrame.
df = pd.read_csv('bse_dataset4.csv')
md = df['Age'].mode().iloc[0]
print(md)
df['Age'].fillna(md, inplace=True)
# Out:
# 21.0

# %%
# Return rows with the mode.
fi_df = df[df['Age'] == md]
fi_df
# Out:
#                Timestamp   gender   Age      emotion   YOB  CGPA  \
# 0    05/07/2023 09:38:39     Male  21.0      Content  2002  4.22
# 3    05/07/2023 09:39:12     Male  21.0        Happy  2003  4.37
# 4    05/07/2023 09:39:14   Female  21.0        Happy  2002  3.63
# 6    05/07/2023 09:39:21   female  21.0   irritated   2001  3.88
# 15   05/07/2023 09:39:46     Male  21.0        Jolly  2002   4.5
# ..                   ...      ...   ...          ...   ...   ...
# 157  05/07/2023 09:42:48  Female   21.0       Happy   2002  3.67
# 160  05/07/2023 09:43:08   Female  21.0  Nonchalant   2002   4.5
# 162  05/07/2023 09:43:36     male  21.0     stressed  2002   4.4
# 163  05/07/2023 09:43:56     Male  21.0      Relaxed  2001   4.5
# 167  05/07/2023 09:44:35   Female  21.0          sad  2001   3.8
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# 0                                        No                      No
# ...

# %%
# Wrong format.
# Row at position 5 has NaN, so we fill it with a default date.
df['Timestamp'].fillna("05/07/2023 09:45:13", inplace=True)
df.iloc[5]
# Out:
# Timestamp                                             05/07/2023 09:45:13
# gender                                                             Female
# Age                                                                  23.0
# emotion                                                            Happy
# YOB                                                                  2000
# CGPA                                                                  3.8
# Do you have a Girl Friend or BOY Friend                                No
# Do you have Depression?                                                No
# Do you have Anxiety?                                                   No
# Do you have Panic attack?                                              No
# Did you have seek any specialist for a treatment?                      No
# Duration                                                               60
# Pulse                                                                 102
# ...

# %%
# Convert the 'Timestamp' column to datetime format
df['Timestamp'] = pd.to_datetime(df['Timestamp'], errors='coerce')
df.head(15)
# Out:
#              Timestamp         gender   Age               emotion   YOB  CGPA  \
# 0  2023-05-07 09:38:39           Male  21.0               Content  2002  4.22
# 1  2023-05-07 09:38:57  Marabou stock  45.0                 Weird  2100   8.9
# 2  2023-05-07 09:39:09        Female   20.0                 Happy  2002  3.98
# 3  2023-05-07 09:39:12           Male  21.0                 Happy  2003  4.37
# 4  2023-05-07 09:39:14         Female  21.0                 Happy  2002  3.63
# 5  2023-05-07 09:45:13         Female  23.0                Happy   2000   3.8
# 6  2023-05-07 09:39:21         female  21.0            irritated   2001  3.88
# 7  2023-05-07 09:39:23        Female   22.0  In a state of wonder  2001  3.79
# 8  2023-05-07 09:39:26           Male  22.0                   Sad  2001   4.7
# 9  2023-05-07 09:39:27         Female  20.0                 happy  2002     4
# 10                 NaT           Male  24.0                 Happy  1998   3.9
# ...

# %%
# Wrong data.  .. 23000 instead of 23   ..  21.99 instead of 2199
for x in df.index:
    if df.loc[x, 'gender'] == 'Marabou Stock':
        df.drop(x, inplace=True)

# %%
# Check if there are any duplicates
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates(inplace=True)

# %%
# Confirm that the duplicates are dropped
df.duplicated().sum()
# Out:
# 0

# %%
# Data Visualization. 
# Plotting heatmaps, piecharts, barplots, lineplots, scatterplots, histograms, boxplots.

# %%
plt.hist(df['Age'], bins=30)
plt.xlabel('Age')
plt.ylabel('Number of students')
plt.title('Histogram')
plt.show()

# %%
# Count the frequency of each age
age_counts = df['Age'].value_counts()

# Create the pie chart
plt.pie(age_counts, labels=age_counts.index, autopct='%1.1f%%')
plt.axis('equal')
plt.title('Age Distribution of Students.')
plt.show()

# %%
# Count the frequency of each age
age_counts = df['Age'].value_counts().sort_index()

# Create the bar plot
plt.bar(age_counts.index, age_counts.values)
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Bar plot showing age distribution of students.')
plt.show()

# %%
# Statistics for Data Science
# Descriptive Statistics , Measures central tendency (Mean,Mode,Median) , Measure dispersion (standard deviation)
# Inferential Statistics ( make predictions, identify variables and hypothesis)
# Modeling 
# ML ( regression, classification, clustering, anomaly detection)

# %% [markdown]
# **PYTHON DATA CORRELATION**

# %% [markdown]
# corr() method is used to calculate the correlation coefficients between all columns in the dataframe.
# Strong positive correlation 1 Strong negative correlation -1
# Perfect correlation
